# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import mixedlm
from statsmodels.stats.multitest import multipletests
from itertools import combinations
import scipy
from scipy.stats import boxcox
plt.rcParams["axes.spines.left"] = True
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.bottom"] = True
plt.rcParams["svg.fonttype"] = "none"
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mizbili\AppData\Local\Temp\ipykernel_19552\2815526516.py", line 3, in <module>
#     import seaborn as sns
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\seaborn\rcmod.py", line 5, in <module>
#     from . import palettes
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\seaborn\utils.py", line 11, in <module>
#     import pandas as pd
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\__init__.py", line 61, in <module>
#     from pandas.core.api import (
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 66, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py", line 61, in <module>
#     from pandas.core import (
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
#Analyses electrophysiological parameters

df_stats=pd.read_csv('Electrophys_params_dataframe.csv')

list_params=[
"Rm",
"Cm",
"RMP",
"AP_Threshold",
"AP_HW",
"AP_Peak",
]

    
for param in list_params:

    print()
    print()
    print("Analyse of ",param)
    print()
    print()
    
    df_taken=df_stats.copy()
    df_taken=df_taken.dropna(subset=param)
    df_taken = df_taken.reset_index(drop=True)
    df_taken=df_taken.copy()

    print()
    print()
    print('Summary of the MLMR no BoxCox transformation')
    df_taken["Animal_Condition_Sex"] = pd.Categorical(df_taken["Animal_Condition_Sex"], categories=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"])
    model = mixedlm(
        param + " ~ C(Animal_Condition_Sex)",  # fixed effects
        data=df_taken,
        groups=df_taken["Cell_Name"],         # random intercepts per patient
        vc_formula={"Animal_Name": "0 + C(Animal_Name)"}
    )
    result = model.fit()
    print(result.summary())

    # Add residuals and fitted values to your dataframe
    df_taken["residuals"] = result.resid
    df_taken["fitted"] = result.fittedvalues
    
    # QQ plot of residuals
    print()
    print()
    print('QQ plot no BoxCox transformation')
    sm.qqplot(df_taken["residuals"], line="45", fit = True)
    plt.title("QQ plot of residuals")
    plt.show()


    if param not in ["AP_HW"]:
    
        # Get the fixed effect estimates:
        fe_params = result.params.filter(like="C(Animal_Condition_Sex)")
        
        # The base (reference) category intercept:
        intercept = result.params["Intercept"]
        
        # Extract all category names:
        categories = df_taken["Animal_Condition_Sex"].astype("category").cat.categories.tolist()
        
        # Construct estimated marginal means (group means) from params:
        # The reference category mean is intercept, others = intercept + coef
        marginal_means = {categories[0]: intercept}  # reference level
        
        for cat in categories[1:]:
            coef_name = f"C(Animal_Condition_Sex)[T.{cat}]"
            marginal_means[cat] = intercept + fe_params.get(coef_name, 0)
        
        print("Estimated marginal means (fixed effects):")
        for k, v in marginal_means.items():
            print(f"{k}: {v}")
        
        # Now compute all pairwise differences and p-values using covariance matrix and t-lengthribution
        cov = result.cov_params()
        
        def get_se_diff(cat1, cat2):
            # Variance of difference Var(b1 - b2) = Var(b1) + Var(b2) - 2*Cov(b1,b2)
            # "Intercept" is included, handle differences with intercept carefully
            
            if cat1 == categories[0] and cat2 == categories[0]:
                return 0  # same group
            elif cat1 == categories[0]:
                # difference = Intercept - (Intercept + b_cat2) = -b_cat2
                param = f"C(Animal_Condition_Sex)[T.{cat2}]"
                var_diff = cov.loc[param, param]
            elif cat2 == categories[0]:
                # difference = (Intercept + b_cat1) - Intercept = b_cat1
                param = f"C(Animal_Condition_Sex)[T.{cat1}]"
                var_diff = cov.loc[param, param]
            else:
                param1 = f"C(Animal_Condition_Sex)[T.{cat1}]"
                param2 = f"C(Animal_Condition_Sex)[T.{cat2}]"
                var1 = cov.loc[param1, param1]
                var2 = cov.loc[param2, param2]
                cov12 = cov.loc[param1, param2]
                var_diff = var1 + var2 - 2*cov12
        
            return np.sqrt(var_diff)
        

        
        alpha = 0.05
        df_resid = result.df_resid if hasattr(result, "df_resid") else result.nobs - len(result.params)
        
        pairwise_results = []
        
        for cat1, cat2 in combinations(categories, 2):
            diff = marginal_means[cat1] - marginal_means[cat2]
            se_diff = get_se_diff(cat1, cat2)
            t_stat = diff / se_diff
            
            # Two-sided p-value from t-lengthribution
            pval = 2 * scipy.stats.t.sf(np.abs(t_stat), df=df_resid)
            
            pairwise_results.append((cat1, cat2, diff, se_diff, t_stat, pval))
        
        # Multiple testing correction (e.g., Benjamini-Hochberg FDR)
        pvals = [x[5] for x in pairwise_results]
        reject, pvals_corrected, _, _ = multipletests(pvals, alpha=alpha, method="fdr_bh")
        
        print("\nPairwise comparisons:")
        print("Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant")
        for i, (cat1, cat2, diff, se_diff, t_stat, pval) in enumerate(pairwise_results):
            print(f"{cat1} vs {cat2} | {diff:.4f} | {se_diff:.4f} | {t_stat:.3f} | {pval:.4f} | {pvals_corrected[i]:.4f} | {reject[i]}")
        
        plt.figure(figsize=(6,6))
        # Bar plot (mean + error bars)
        sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k", 
                        order=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],
                        facecolor=[0,0,0,0], edgecolor="black")
        # Overlay scatter plot for individual points
        sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
                          order=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],
                          palette=["k","r","dimgrey","darkorange"], size=6, jitter=True)
        plt.ylabel(param)
        plt.savefig(param+"_male_female.svg")
        plt.show()
            
        for animal_condition,color in zip(["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],["k","r","dimgrey","darkorange"]):
            df_reg=df_taken.copy()
            df_reg=df_reg.loc[df_reg["Animal_Condition_Sex"] == animal_condition]
            df_reg=df_reg.dropna(subset="days_post_surgery")
            x=df_reg["days_post_surgery"]
            y=df_reg[param]
            res = scipy.stats.linregress(x, y)
            if res.pvalue<1:
                print("r2 regression "+animal_condition+" : ", res.rvalue**2)
                print("pvalue "+animal_condition+" : ", res.pvalue)
                plt.plot(df_reg["days_post_surgery"],df_reg[param],"o",color=color)
                plt.plot(x, res.intercept + res.slope*x,color=color)
                plt.ylabel(param)
                plt.xlabel("days_post_surgery")
        plt.savefig("correlation_"+param+"_male_female.svg")
        plt.show()
    
    
        print()
        print()
        print()
        print()
        print()
        print()


    
    else:
    
        c_boxcox=0.1
        data_pos = df_taken[param] + c_boxcox
        bc_transformed, fitted_lambda = boxcox(data_pos)
        df_taken[param + "_bc"] = bc_transformed

        print()
        print()
        print('Summary of the MLMR with BoxCox transformation')
        df_taken["Animal_Condition_Sex"] = pd.Categorical(df_taken["Animal_Condition_Sex"], categories=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"])
        model = mixedlm(
            param + "_bc" + " ~ C(Animal_Condition_Sex)",  # fixed effects
            data=df_taken,
            groups=df_taken["Cell_Name"],         # random intercepts per patient
            vc_formula={"Animal_Name": "0 + C(Animal_Name)"}
        )
        result = model.fit()
        print(result.summary())
        
        # Add residuals and fitted values to your dataframe
        df_taken["residuals"] = result.resid
        df_taken["fitted"] = result.fittedvalues
        
        # QQ plot of residuals
        print()
        print()
        print('QQ plot with BoxCox transformation')
        sm.qqplot(df_taken["residuals"], line="45", fit = True)
        plt.title("QQ plot of residuals")
        plt.show()
        
        # Get the fixed effect estimates:
        fe_params = result.params.filter(like="C(Animal_Condition_Sex)")
        
        # The base (reference) category intercept:
        intercept = result.params["Intercept"]
        
        # Extract all category names:
        categories = df_taken["Animal_Condition_Sex"].astype("category").cat.categories.tolist()
        
        # Construct estimated marginal means (group means) from params:
        # The reference category mean is intercept, others = intercept + coef
        marginal_means = {categories[0]: intercept}  # reference level
        
        for cat in categories[1:]:
            coef_name = f"C(Animal_Condition_Sex)[T.{cat}]"
            marginal_means[cat] = intercept + fe_params.get(coef_name, 0)
        
        print("Estimated marginal means Box-Cox scale(fixed effects):")
        for k, v in marginal_means.items():
            print(f"{k}: {v}")
        
        # Now compute all pairwise differences and p-values using covariance matrix and t-distribution
        cov = result.cov_params()
        
        def get_se_diff(cat1, cat2):
            # Variance of difference Var(b1 - b2) = Var(b1) + Var(b2) - 2*Cov(b1,b2)
            # "Intercept" is included, handle differences with intercept carefully
            
            if cat1 == categories[0] and cat2 == categories[0]:
                return 0  # same group
            elif cat1 == categories[0]:
                # difference = Intercept - (Intercept + b_cat2) = -b_cat2
                param = f"C(Animal_Condition_Sex)[T.{cat2}]"
                var_diff = cov.loc[param, param]
            elif cat2 == categories[0]:
                # difference = (Intercept + b_cat1) - Intercept = b_cat1
                param = f"C(Animal_Condition_Sex)[T.{cat1}]"
                var_diff = cov.loc[param, param]
            else:
                param1 = f"C(Animal_Condition_Sex)[T.{cat1}]"
                param2 = f"C(Animal_Condition_Sex)[T.{cat2}]"
                var1 = cov.loc[param1, param1]
                var2 = cov.loc[param2, param2]
                cov12 = cov.loc[param1, param2]
                var_diff = var1 + var2 - 2*cov12
        
            return np.sqrt(var_diff)
                
        alpha = 0.05
        df_resid = result.df_resid if hasattr(result, "df_resid") else result.nobs - len(result.params)
        
        pairwise_results = []
        
        for cat1, cat2 in combinations(categories, 2):
            diff = marginal_means[cat1] - marginal_means[cat2]
            se_diff = get_se_diff(cat1, cat2)
            t_stat = diff / se_diff
            
            # Two-sided p-value from t-distribution
            pval = 2 * scipy.stats.t.sf(np.abs(t_stat), df=df_resid)
            
            pairwise_results.append((cat1, cat2, diff, se_diff, t_stat, pval))
        
        # Multiple testing correction (e.g., Benjamini-Hochberg FDR)
        pvals = [x[5] for x in pairwise_results]
        reject, pvals_corrected, _, _ = multipletests(pvals, alpha=alpha, method="fdr_bh")
        
        print("\nPairwise comparisons:")
        print("Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant")
        for i, (cat1, cat2, diff, se_diff, t_stat, pval) in enumerate(pairwise_results):
            print(f"{cat1} vs {cat2} | {diff:.4f} | {se_diff:.4f} | {t_stat:.3f} | {pval:.4f} | {pvals_corrected[i]:.4f} | {reject[i]}")


        plt.figure(figsize=(6,6))
        # Bar plot (mean + error bars)
        sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k", 
                        order=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],
                        facecolor=[0,0,0,0], edgecolor="black")
        # Overlay scatter plot for individual points
        sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
                          order=["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],
                          palette=["k","r","dimgrey","darkorange"], size=6, jitter=True)
        plt.ylabel(param)
        plt.savefig(param+"_male_female.svg")
        plt.show()
        
    
        for animal_condition,color in zip(["SHAM_Male","LNIO_Male","SHAM_Female","LNIO_Female"],["k","r","dimgrey","darkorange"]):
            df_reg=df_taken.copy()
            df_reg=df_reg.loc[df_reg["Animal_Condition_Sex"] == animal_condition]
            df_reg=df_reg.dropna(subset="days_post_surgery")
            x=df_reg["days_post_surgery"]
            y=df_reg[param]
            res = scipy.stats.linregress(x, y)
            if res.pvalue<1:
                print("r2 regression "+animal_condition+" : ", res.rvalue**2)
                print("pvalue "+animal_condition+" : ", res.pvalue)
                plt.plot(df_reg["days_post_surgery"],df_reg[param],"o",color=color)
                plt.plot(x, res.intercept + res.slope*x,color=color)
                plt.ylabel(param)
                plt.xlabel("days_post_surgery")
        plt.savefig("correlation_"+param+"_male_female.svg")
        plt.show()


        print()
        print()
        print()
        print()
        print()
        print()
# Out:
#         Cell_Name Animal_Name Animal_Condition_Sex  days_post_surgery     Rm  \
# 0     2023_07_07A  2023_07_07            SHAM_Male                 24   41.0
# 1     2023_07_07B  2023_07_07            SHAM_Male                 24   68.5
# 2     2023_07_07C  2023_07_07            SHAM_Male                 24   47.5
# 3     2023_07_07D  2023_07_07            SHAM_Male                 24   58.0
# 4     2024_01_11C  2024_01_11            SHAM_Male                 24  101.5
# ..            ...         ...                  ...                ...    ...
# 91  2025_04_08_1A  2025_04_08          LNIO_Female                 22  138.0
# 92  2025_04_08_1B  2025_04_08          LNIO_Female                 22  228.5
# 93  2025_04_08_1C  2025_04_08          LNIO_Female                 22  111.0
# 94  2025_04_08_2D  2025_04_08          LNIO_Female                 22   43.5
# 95  2025_04_08_4G  2025_04_08          LNIO_Female                 22   56.0
#
#             Cm        RMP  AP_Threshold     AP_HW    AP_Peak
# 0   372.585935        NaN    -56.426610  0.981065  47.233390
# 1   289.314187 -60.458450    -45.957910  0.919428  48.752090
# 2   348.988266 -70.184326    -42.749577  0.867896  31.540423
# 3   293.663431 -63.883193    -45.839010  1.088700  52.180990
# 4   134.546669 -66.263482    -43.294598  1.103020  37.755402
# ..         ...        ...           ...       ...        ...
# 91  108.972464 -67.915600    -42.850000  1.113050  54.840000
# 92   61.856455 -68.583500    -43.510000  1.138670  49.520000
# 93  171.474775 -65.103200    -48.080000  1.173710  46.390000
# 94  268.809195 -60.636150    -54.240000  0.999755  53.560000
# 95  263.291071 -64.707200    -51.330000  0.989900  50.200000
#
# [96 rows x 10 columns]
#
#
# Analyse of  Rm
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                        Mixed Linear Model Regression Results
# ===================================================================================
# Model:                      MixedLM          Dependent Variable:          Rm
# No. Observations:           96               Method:                      REML
# No. Groups:                 96               Scale:                       1283.0349
# Min. group size:            1                Log-Likelihood:              -497.8934
# Max. group size:            1                Converged:                   Yes
# Mean group size:            1.0
# -----------------------------------------------------------------------------------
#                                         Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------
# Intercept                                77.694    3.216 24.156 0.000 71.390 83.998
# C(Animal_Condition_Sex)[T.LNIO_Male]     29.913    4.889  6.118 0.000 20.330 39.495
# C(Animal_Condition_Sex)[T.SHAM_Female]   65.712   12.802  5.133 0.000 40.620 90.804
# C(Animal_Condition_Sex)[T.LNIO_Female]   55.414   10.287  5.387 0.000 35.253 75.576
# Animal_Name Var                        1283.035
# ===================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# Estimated marginal means (fixed effects):
# SHAM_Male: 77.69426375941238
# LNIO_Male: 107.60679038780603
# SHAM_Female: 143.40625
# LNIO_Female: 133.1086956521739
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | -29.9125 | 4.8893 | -6.118 | 0.0000 | 0.0000 | True
# SHAM_Male vs SHAM_Female | -65.7120 | 12.8024 | -5.133 | 0.0000 | 0.0000 | True
# SHAM_Male vs LNIO_Female | -55.4144 | 10.2866 | -5.387 | 0.0000 | 0.0000 | True
# LNIO_Male vs SHAM_Female | -35.7995 | 14.9768 | -2.390 | 0.0189 | 0.0283 | True
# LNIO_Male vs LNIO_Female | -25.5019 | 13.2983 | -1.918 | 0.0583 | 0.0699 | False
# SHAM_Female vs LNIO_Female | 10.2976 | 16.4860 | 0.625 | 0.5338 | 0.5338 | False
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# r2 regression SHAM_Male :  0.00862849054695997
# pvalue SHAM_Male :  0.7052611382222865
# r2 regression LNIO_Male :  0.0002504311565463203
# pvalue LNIO_Male :  0.9248716350908377
# r2 regression SHAM_Female :  0.007521913345436862
# pvalue SHAM_Female :  0.7494405731871983
# r2 regression LNIO_Female :  0.07850031949732839
# pvalue LNIO_Female :  0.1953622785848858
# Analyse of  Cm
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                         Mixed Linear Model Regression Results
# ======================================================================================
# Model:                       MixedLM           Dependent Variable:           Cm
# No. Observations:            96                Method:                       REML
# No. Groups:                  96                Scale:                        3386.1909
# Min. group size:             1                 Log-Likelihood:               -542.5354
# Max. group size:             1                 Converged:                    Yes
# Mean group size:             1.0
# --------------------------------------------------------------------------------------
#                                         Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------------------------------
# Intercept                               260.254    6.441 40.407 0.000  247.631 272.878
# C(Animal_Condition_Sex)[T.LNIO_Male]    -11.100   18.510 -0.600 0.549  -47.379  25.179
# C(Animal_Condition_Sex)[T.SHAM_Female]  -80.226   23.345 -3.437 0.001 -125.981 -34.470
# C(Animal_Condition_Sex)[T.LNIO_Female]  -67.283   20.288 -3.316 0.001 -107.046 -27.520
# Animal_Name Var                        3386.191
# ======================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# Estimated marginal means (fixed effects):
# SHAM_Male: 260.2544157600328
# LNIO_Male: 249.15424812786344
# SHAM_Female: 180.028882955965
# LNIO_Female: 192.97140673030796
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | 11.1002 | 18.5100 | 0.600 | 0.5502 | 0.6302 | False
# SHAM_Male vs SHAM_Female | 80.2255 | 23.3449 | 3.437 | 0.0009 | 0.0039 | True
# SHAM_Male vs LNIO_Female | 67.2830 | 20.2875 | 3.316 | 0.0013 | 0.0039 | True
# LNIO_Male vs SHAM_Female | 69.1254 | 24.4817 | 2.824 | 0.0058 | 0.0116 | True
# LNIO_Male vs LNIO_Female | 56.1828 | 21.6812 | 2.591 | 0.0111 | 0.0167 | True
# SHAM_Female vs LNIO_Female | -12.9425 | 26.7900 | -0.483 | 0.6302 | 0.6302 | False
# r2 regression SHAM_Male :  0.034809064651454884
# pvalue SHAM_Male :  0.4443964565173337
# r2 regression LNIO_Male :  0.05424477811467736
# pvalue LNIO_Male :  0.15936787755924503
# r2 regression SHAM_Female :  0.003387793064808576
# pvalue SHAM_Female :  0.8304584279873011
# r2 regression LNIO_Female :  0.0002520418518514648
# pvalue LNIO_Female :  0.9426846068220874
# Analyse of  RMP
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                         Mixed Linear Model Regression Results
# =====================================================================================
# Model:                      MixedLM           Dependent Variable:           RMP
# No. Observations:           95                Method:                       REML
# No. Groups:                 95                Scale:                        32.5260
# Min. group size:            1                 Log-Likelihood:               -325.3124
# Max. group size:            1                 Converged:                    Yes
# Mean group size:            1.0
# -------------------------------------------------------------------------------------
#                                         Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------------------
# Intercept                              -61.005    0.625 -97.536 0.000 -62.231 -59.779
# C(Animal_Condition_Sex)[T.LNIO_Male]    -2.580    1.857  -1.389 0.165  -6.220   1.060
# C(Animal_Condition_Sex)[T.SHAM_Female]  -2.967    2.111  -1.406 0.160  -7.105   1.171
# C(Animal_Condition_Sex)[T.LNIO_Female]  -2.739    1.703  -1.608 0.108  -6.077   0.600
# Animal_Name Var                         32.526
# =====================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# Estimated marginal means (fixed effects):
# SHAM_Male: -61.00466018348774
# LNIO_Male: -63.584916755015506
# SHAM_Female: -63.971890625
# LNIO_Female: -63.743193478260864
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | 2.5803 | 1.8571 | 1.389 | 0.1681 | 0.3362 | False
# SHAM_Male vs SHAM_Female | 2.9672 | 2.1111 | 1.406 | 0.1633 | 0.3362 | False
# SHAM_Male vs LNIO_Female | 2.7385 | 1.7034 | 1.608 | 0.1114 | 0.3362 | False
# LNIO_Male vs SHAM_Female | 0.3870 | 2.3658 | 0.164 | 0.8704 | 0.9392 | False
# LNIO_Male vs LNIO_Female | 0.1583 | 2.0684 | 0.077 | 0.9392 | 0.9392 | False
# SHAM_Female vs LNIO_Female | -0.2287 | 2.6242 | -0.087 | 0.9307 | 0.9392 | False
# r2 regression SHAM_Male :  0.10370929039131543
# pvalue SHAM_Male :  0.19248668178399372
# r2 regression LNIO_Male :  0.0005604611160139416
# pvalue LNIO_Male :  0.8878057155302358
# r2 regression SHAM_Female :  0.4573588601265964
# pvalue SHAM_Female :  0.004022269148731146
# r2 regression LNIO_Female :  0.000335771438194146
# pvalue LNIO_Female :  0.9338634196682288
# Analyse of  AP_Threshold
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                         Mixed Linear Model Regression Results
# =====================================================================================
# Model:                     MixedLM          Dependent Variable:          AP_Threshold
# No. Observations:          96               Method:                      REML
# No. Groups:                96               Scale:                       12.6844
# Min. group size:           1                Log-Likelihood:              -285.5295
# Max. group size:           1                Converged:                   Yes
# Mean group size:           1.0
# -------------------------------------------------------------------------------------
#                                         Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------------------
# Intercept                              -47.095    1.150 -40.964 0.000 -49.349 -44.842
# C(Animal_Condition_Sex)[T.LNIO_Male]     0.460    1.094   0.420 0.674  -1.684   2.603
# C(Animal_Condition_Sex)[T.SHAM_Female]  -0.697    1.664  -0.419 0.675  -3.958   2.563
# C(Animal_Condition_Sex)[T.LNIO_Female]  -0.173    1.561  -0.111 0.911  -3.232   2.885
# Animal_Name Var                         12.684
# =====================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# Estimated marginal means (fixed effects):
# SHAM_Male: -47.095215157894735
# LNIO_Male: -46.63535800000001
# SHAM_Female: -47.792500000000004
# LNIO_Female: -47.26869565217391
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | -0.4599 | 1.0936 | -0.420 | 0.6751 | 0.8890 | False
# SHAM_Male vs SHAM_Female | 0.6973 | 1.6637 | 0.419 | 0.6761 | 0.8890 | False
# SHAM_Male vs LNIO_Female | 0.1735 | 1.5606 | 0.111 | 0.9117 | 0.9117 | False
# LNIO_Male vs SHAM_Female | 1.1571 | 1.4128 | 0.819 | 0.4149 | 0.8890 | False
# LNIO_Male vs LNIO_Female | 0.6333 | 0.9319 | 0.680 | 0.4984 | 0.8890 | False
# SHAM_Female vs LNIO_Female | -0.5238 | 1.5788 | -0.332 | 0.7408 | 0.8890 | False
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# r2 regression SHAM_Male :  0.1271175750373879
# pvalue SHAM_Male :  0.13404308905464007
# r2 regression LNIO_Male :  0.028764861141008326
# pvalue LNIO_Male :  0.30869166030212364
# r2 regression SHAM_Female :  0.016029291546545213
# pvalue SHAM_Female :  0.6403317543825612
# r2 regression LNIO_Female :  0.09652830010434506
# pvalue LNIO_Female :  0.14904360880677406
# Analyse of  AP_HW
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                     MixedLM          Dependent Variable:          AP_HW
# No. Observations:          96               Method:                      REML
# No. Groups:                96               Scale:                       0.0376
# Min. group size:           1                Log-Likelihood:              -17.7055
# Max. group size:           1                Converged:                   Yes
# Mean group size:           1.0
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                               1.122    0.016 68.921 0.000  1.090  1.154
# C(Animal_Condition_Sex)[T.LNIO_Male]   -0.003    0.057 -0.047 0.963 -0.115  0.109
# C(Animal_Condition_Sex)[T.SHAM_Female]  0.053    0.078  0.687 0.492 -0.099  0.206
# C(Animal_Condition_Sex)[T.LNIO_Female]  0.081    0.063  1.281 0.200 -0.043  0.205
# Animal_Name Var                         0.038
# =================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Estimated marginal means (fixed effects):
# SHAM_Male: 1.1223166842105283
# LNIO_Male: 1.1196534210526319
# SHAM_Female: 1.1757228622093203
# LNIO_Female: 1.2031800000000001
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | 0.0027 | 0.0572 | 0.047 | 0.9630 | 0.9630 | False
# SHAM_Male vs SHAM_Female | -0.0534 | 0.0777 | -0.687 | 0.4936 | 0.7412 | False
# SHAM_Male vs LNIO_Female | -0.0809 | 0.0631 | -1.281 | 0.2035 | 0.7412 | False
# LNIO_Male vs SHAM_Female | -0.0561 | 0.0817 | -0.686 | 0.4941 | 0.7412 | False
# LNIO_Male vs LNIO_Female | -0.0835 | 0.0722 | -1.157 | 0.2504 | 0.7412 | False
# SHAM_Female vs LNIO_Female | -0.0275 | 0.0890 | -0.308 | 0.7585 | 0.9102 | False
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# r2 regression SHAM_Male :  0.057699788504632164
# pvalue SHAM_Male :  0.32189936052572077
# r2 regression LNIO_Male :  0.0015999283954366283
# pvalue LNIO_Male :  0.8115478944557507
# r2 regression SHAM_Female :  0.14522464324124815
# pvalue SHAM_Female :  0.14530635329003236
# r2 regression LNIO_Female :  0.03638941701072828
# pvalue LNIO_Female :  0.38327300121894314
# Analyse of  AP_Peak
#
#
#
#
# Summary of the MLMR no BoxCox transformation
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                     MixedLM          Dependent Variable:          AP_Peak
# No. Observations:          96               Method:                      REML
# No. Groups:                96               Scale:                       13.1220
# Min. group size:           1                Log-Likelihood:              -287.0896
# Max. group size:           1                Converged:                   Yes
# Mean group size:           1.0
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                              48.202    0.380 126.787 0.000 47.457 48.947
# C(Animal_Condition_Sex)[T.LNIO_Male]    0.401    1.148   0.349 0.727 -1.850  2.651
# C(Animal_Condition_Sex)[T.SHAM_Female] -0.968    1.171  -0.827 0.408 -3.263  1.326
# C(Animal_Condition_Sex)[T.LNIO_Female]  1.367    1.113   1.228 0.219 -0.814  3.547
# Animal_Name Var                        13.122
# ==================================================================================
#
#
#
# QQ plot no BoxCox transformation
# C:\Users\mizbili\AppData\Local\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:236: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(data=df_taken, x="Animal_Condition_Sex", y=param, errorbar="se", errcolor="k",
# C:\Users\mizbili\AppData\Local\Temp\ipykernel_22344\2634134136.py:240: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df_taken, x="Animal_Condition_Sex", y=param,
# Estimated marginal means (fixed effects):
# SHAM_Male: 48.20215326315785
# LNIO_Male: 48.60272094736841
# SHAM_Female: 47.23375000000001
# LNIO_Female: 49.568695652173915
#
# Pairwise comparisons:
# Category1 vs Category2 | Mean Diff | SE Diff | t-stat | p-value | p-value (adj) | Significant
# SHAM_Male vs LNIO_Male | -0.4006 | 1.1480 | -0.349 | 0.7280 | 0.7280 | False
# SHAM_Male vs SHAM_Female | 0.9684 | 1.1708 | 0.827 | 0.4103 | 0.5623 | False
# SHAM_Male vs LNIO_Female | -1.3665 | 1.1126 | -1.228 | 0.2225 | 0.5623 | False
# LNIO_Male vs SHAM_Female | 1.3690 | 1.4688 | 0.932 | 0.3538 | 0.5623 | False
# LNIO_Male vs LNIO_Female | -0.9660 | 1.3272 | -0.728 | 0.4686 | 0.5623 | False
# SHAM_Female vs LNIO_Female | -2.3349 | 1.6608 | -1.406 | 0.1631 | 0.5623 | False
# r2 regression SHAM_Male :  0.13930039169351285
# pvalue SHAM_Male :  0.11550551786577408
# r2 regression LNIO_Male :  0.051623528746567615
# pvalue LNIO_Male :  0.17011425919887746
# r2 regression SHAM_Female :  0.0004646009497419258
# pvalue SHAM_Female :  0.9368472933415926
# r2 regression LNIO_Female :  0.10740648547708266
# pvalue LNIO_Female :  0.12685941972773332
